# %% [markdown]
# # Linear Regression
# Fitting straight lines to data.
#
# What is the regression?

# %%
import pandas as pd
import matplotlib.pyplot as plt

def main():
    df = pd.read_csv("data/weights.csv", index_col=0, sep="\s+")

    fig = plt.figure()
    ax = fig.add_subplot()
    ax.suptitle("Date")

    print(df)


if __name__ == "__main__":
    main()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/qk/cxrw5b4n6mz81fqsk05vkx3c0000gq/T/ipykernel_60788/895766459.py:5: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("data/weights.csv", index_col=0, sep="\s+")
#             weight
# date
# 20.05.2022    94.4
# 21.05.2022    93.0
# 22.05.2022    93.4
# 23.05.2022    93.4
# 24.05.2022    93.1
# ...            ...
# 16.08.2022    82.9
# 17.08.2022    82.5
# 18.08.2022    82.5
# 19.08.2022    82.0
# 20.08.2022    82.6
#
# [93 rows x 1 columns]
